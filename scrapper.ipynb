# %% [markdown]
# # NYTConnections Scrapper
#
# **Author:** Eric Nunes
#
# **Originally Created:** 11 October 2024
#
# This notebook aims to scrape the information from the NYT Connections games and post regular updates to the corresponding dataset. You can find the Kaggle dataset [here](https://www.kaggle.com/datasets/eric27n/the-new-york-times-connections/data).

# %%
import numpy as np
import pandas as pd
import requests
import json
from datetime import datetime, timedelta

# %%
def reformat_date(date_str):
    try:
        original_date = datetime.strptime(date_str, "%m/%d/%Y")
        new_date_str = original_date.strftime("%Y-%m-%d")
        return new_date_str
    except ValueError:
        return date_str

# %%
today_date = datetime.now().date()
yesterday_date = today_date - timedelta(1)
tomorrow_date = today_date + timedelta(1)
datetimes = [yesterday_date, today_date, tomorrow_date] # adjust datetimes as needed

start_date = "2024-11-01"
end_date = "2024-11-15"
date_range = pd.date_range(start=start_date, end=end_date, freq="D").tolist()
datetimes = [date.date() for date in date_range]
print(datetimes)

df = pd.read_csv("hf://datasets/eric27n/NYT-Connections/Connections_Data.csv")

game_ids = []
dates = []
words = []
group_names = []
word_levels = []
rows = []
columns = []
# Out:
# [datetime.date(2024, 11, 1), datetime.date(2024, 11, 2), datetime.date(2024, 11, 3), datetime.date(2024, 11, 4), datetime.date(2024, 11, 5), datetime.date(2024, 11, 6), datetime.date(2024, 11, 7), datetime.date(2024, 11, 8), datetime.date(2024, 11, 9), datetime.date(2024, 11, 10), datetime.date(2024, 11, 11), datetime.date(2024, 11, 12), datetime.date(2024, 11, 13), datetime.date(2024, 11, 14), datetime.date(2024, 11, 15)]

# %%
# Editor's Note 2024-10-26:
#     A Row where the word was "NA" was improperly read as NaN (not a number/null).
#     This row is to rectify this problem.
display(df[df['Word'].isnull()])
df.loc[978, 'Word'] = "NA"
display(df[df['Word'].isnull()])
display(df[df['Game ID'] == 62])
print(len(df))
# Out:
#      Game ID Puzzle Date Word              Group Name  Group Level  \
# 978       62  2023-08-12  NaN  PERIODIC TABLE SYMBOLS            3
#
#      Starting Row  Starting Column
# 978             1                3
# Empty DataFrame
# Columns: [Game ID, Puzzle Date, Word, Group Name, Group Level, Starting Row, Starting Column]
# Index: []
#      Game ID Puzzle Date Word              Group Name  Group Level  \
# 976       62  2023-08-12   MA     STATE ABBREVIATIONS            0
# 977       62  2023-08-12   LA           MUSICAL NOTES            1
# 978       62  2023-08-12   NA  PERIODIC TABLE SYMBOLS            3
# 979       62  2023-08-12   NU           GREEK LETTERS            2
# 980       62  2023-08-12   PI           GREEK LETTERS            2
# 981       62  2023-08-12   NI  PERIODIC TABLE SYMBOLS            3
# 982       62  2023-08-12   TI           MUSICAL NOTES            1
# 983       62  2023-08-12   HE  PERIODIC TABLE SYMBOLS            3
# 984       62  2023-08-12   FA           MUSICAL NOTES            1
# 985       62  2023-08-12   XI           GREEK LETTERS            2
# 986       62  2023-08-12   PA     STATE ABBREVIATIONS            0
# 987       62  2023-08-12   FE  PERIODIC TABLE SYMBOLS            3
# 988       62  2023-08-12   DO           MUSICAL NOTES            1
# 989       62  2023-08-12   CO     STATE ABBREVIATIONS            0
# 990       62  2023-08-12   MU           GREEK LETTERS            2
# 991       62  2023-08-12   ME     STATE ABBREVIATIONS            0
#
#      Starting Row  Starting Column
# 976             1                1
# 977             1                2
# 978             1                3
# 979             1                4
# 980             2                1
# 981             2                2
# 982             2                3
# 983             2                4
# 984             3                1
# 985             3                2
# 986             3                3
# 987             3                4
# 988             4                1
# 989             4                2
# 990             4                3
# 991             4                4
# 8304

# %%
df['Puzzle Date'] = df['Puzzle Date'].apply(reformat_date)
display(df)
# Out:
#       Game ID Puzzle Date      Word      Group Name  Group Level  \
# 0           1  2023-06-12      SNOW     WET WEATHER            0
# 1           1  2023-06-12     LEVEL     PALINDROMES            3
# 2           1  2023-06-12     SHIFT   KEYBOARD KEYS            2
# 3           1  2023-06-12     KAYAK     PALINDROMES            3
# 4           1  2023-06-12      HEAT       NBA TEAMS            1
# ...       ...         ...       ...             ...          ...
# 8299      547  2024-11-11    PAYDAY  CHOCOLATE BARS            0
# 8300      547  2024-11-11      CORE            GIST            1
# 8301      547  2024-11-11      DOVE  CHOCOLATE BARS            0
# 8302      547  2024-11-11      LADY        ___ BIRD            3
# 8303      547  2024-11-11  WIRELESS   KINDS OF BRAS            2
#
#       Starting Row  Starting Column
# 0                1                1
# 1                1                2
# 2                1                3
# 3                1                4
# 4                2                1
# ...            ...              ...
# 8299             3                4
# 8300             4                1
# 8301             4                2
# 8302             4                3
# 8303             4                4
#
# [8304 rows x 7 columns]

# %%
# Print entries for a given date
date = "2024-10-31" # change date as you please
filtered_df = df[df['Puzzle Date'] == date]
result = [row for row in filtered_df['Word'].values]
print(",".join(result))
display(filtered_df)
# Out:
# BAT,EGG,LOVE,WITCH,PUMPKIN,SPIDER,BLINK,JOB,DIABLO,FLUTTER,TREASURE,VIPER,SCAVENGER,MUSTANG,WINK,DARLING
#       Game ID Puzzle Date       Word                           Group Name  \
# 8112      523  2024-10-31        BAT  THINGS YOU CAN DO WITH YOUR EYELIDS
# 8113      523  2024-10-31        EGG                             ___ HUNT
# 8114      523  2024-10-31       LOVE                  TERMS OF ENDEARMENT
# 8115      523  2024-10-31      WITCH                             ___ HUNT
# 8116      523  2024-10-31    PUMPKIN                  TERMS OF ENDEARMENT
# 8117      523  2024-10-31     SPIDER                          SPORTS CARS
# 8118      523  2024-10-31      BLINK  THINGS YOU CAN DO WITH YOUR EYELIDS
# 8119      523  2024-10-31        JOB                             ___ HUNT
# 8120      523  2024-10-31     DIABLO                          SPORTS CARS
# 8121      523  2024-10-31    FLUTTER  THINGS YOU CAN DO WITH YOUR EYELIDS
# 8122      523  2024-10-31   TREASURE                  TERMS OF ENDEARMENT
# 8123      523  2024-10-31      VIPER                          SPORTS CARS
# 8124      523  2024-10-31  SCAVENGER                             ___ HUNT
# 8125      523  2024-10-31    MUSTANG                          SPORTS CARS
# 8126      523  2024-10-31       WINK  THINGS YOU CAN DO WITH YOUR EYELIDS
# 8127      523  2024-10-31    DARLING                  TERMS OF ENDEARMENT
#
#       Group Level  Starting Row  Starting Column
# 8112            1             1                1
# 8113            3             1                2
# 8114            0             1                3
# 8115            3             1                4
# 8116            0             2                1
# 8117            2             2                2
# 8118            1             2                3
# 8119            3             2                4
# 8120            2             3                1
# 8121            1             3                2
# 8122            0             3                3
# 8123            2             3                4
# 8124            3             4                1
# 8125            2             4                2
# 8126            1             4                3
# 8127            0             4                4

# %%
# Run data extraction for today and tomorrow dates.
for date in datetimes:
    url = f"https://www.nytimes.com/svc/connections/v1/{date}.json"
    response = requests.get(url)
    results = json.loads(response.text)
    
    game_ids.extend([results['id']] * 16)
    dates.extend([date.strftime("%Y-%m-%d")] * 16)
    
    starting_board = results['startingGroups']
    for x in range(1, 5):
        for y in range(1, 5):
            word = starting_board[x-1][y-1]
            words.append(word)
            rows.append(x)
            columns.append(y)
            for key in results['groups'].keys():
                if word in results['groups'][key]['members']:
                    group_names.append(key)
                    word_levels.append(results['groups'][key]['level'])
    
    today_df = pd.DataFrame({
        'Game ID': game_ids,
        'Puzzle Date': dates,
        'Word': words,
        'Group Name': group_names,
        'Group Level': word_levels,
        'Starting Row': rows,
        'Starting Column': columns
    })
    
    df = pd.concat([df, today_df], ignore_index=True)
display(df.tail(20))
# Out:
#        Game ID Puzzle Date      Word                     Group Name  \
# 10204      545  2024-11-14     EMPTY                        DEPLETE
# 10205      545  2024-11-14    GROOVE        PLAY MUSIC WITH PASSION
# 10206      545  2024-11-14       TIP  WORDS ON A RESTAURANT RECEIPT
# 10207      545  2024-11-14   EXHAUST                        DEPLETE
# 10208      561  2024-11-15      PIPE      INSTRUMENTS YOU BLOW INTO
# 10209      561  2024-11-15    PHRASE            ELEMENTS OF WRITING
# 10210      561  2024-11-15       JUG      INSTRUMENTS YOU BLOW INTO
# 10211      561  2024-11-15   PASSAGE                    ___ OF TIME
# 10212      561  2024-11-15      LEAK                        FISSURE
# 10213      561  2024-11-15    LETTER            ELEMENTS OF WRITING
# 10214      561  2024-11-15     WASTE                    ___ OF TIME
# 10215      561  2024-11-15   WHISTLE      INSTRUMENTS YOU BLOW INTO
# 10216      561  2024-11-15      NICK                    ___ OF TIME
# 10217      561  2024-11-15     CRACK                        FISSURE
# 10218      561  2024-11-15  RECORDER      INSTRUMENTS YOU BLOW INTO
# 10219      561  2024-11-15      WORD            ELEMENTS OF WRITING
# 10220      561  2024-11-15      HOLE                        FISSURE
# 10221      561  2024-11-15     SANDS                    ___ OF TIME
# 10222      561  2024-11-15  SENTENCE            ELEMENTS OF WRITING
# 10223      561  2024-11-15  PUNCTURE                        FISSURE
#
#        Group Level  Starting Row  Starting Column
# 10204            0             4                1
# 10205            1             4                2
# 10206            2             4                3
# 10207            0             4                4
# 10208            2             1                1
# 10209            1             1                2
# 10210            2             1                3
# 10211            3             1                4
# 10212            0             2                1
# 10213            1             2                2
# 10214            3             2                3
# 10215            2             2                4
# 10216            3             3                1
# 10217            0             3                2
# 10218            2             3                3
# 10219            1             3                4
# 10220            0             4                1
# 10221            3             4                2
# 10222            1             4                3
# 10223            0             4                4

# %%
import pandas as pd

# Count occurrences of each "Puzzle Date"
puzzle_date_counts = df['Puzzle Date'].value_counts()

# Filter dates with less than or more than 16 occurrences
filtered_dates = puzzle_date_counts[(puzzle_date_counts < 16) | (puzzle_date_counts > 16)]

# Print the filtered dates
print(filtered_dates)
display(df[df['Puzzle Date'] == "2024-11-11"])
# Out:
# Puzzle Date
# 2024-11-11    20
# Name: count, dtype: int64
#       Game ID Puzzle Date       Word      Group Name  Group Level  \
# 8288      547  2024-11-11     CRUNCH  CHOCOLATE BARS            0
# 9344      547  2024-11-11     CRUNCH      CANDY BARS            0
# 8289      547  2024-11-11  SUBSTANCE            GIST            1
# 8290      547  2024-11-11       DEMI   KINDS OF BRAS            2
# 8291      547  2024-11-11        SUE        ___ BIRD            3
# 8292      547  2024-11-11        BIG        ___ BIRD            3
# 8293      547  2024-11-11     THRUST            GIST            1
# 8294      547  2024-11-11     SPORTS   KINDS OF BRAS            2
# 8295      547  2024-11-11    PUSH-UP   KINDS OF BRAS            2
# 8296      547  2024-11-11       MARS  CHOCOLATE BARS            0
# 9352      547  2024-11-11       MARS      CANDY BARS            0
# 8297      547  2024-11-11       MEAT            GIST            1
# 8298      547  2024-11-11      EARLY        ___ BIRD            3
# 8299      547  2024-11-11     PAYDAY  CHOCOLATE BARS            0
# 9355      547  2024-11-11     PAYDAY      CANDY BARS            0
# 8300      547  2024-11-11       CORE            GIST            1
# 8301      547  2024-11-11       DOVE  CHOCOLATE BARS            0
# 9357      547  2024-11-11       DOVE      CANDY BARS            0
# 8302      547  2024-11-11       LADY        ___ BIRD            3
# 8303      547  2024-11-11   WIRELESS   KINDS OF BRAS            2
#
#       Starting Row  Starting Column
# 8288             1                1
# 9344             1                1
# 8289             1                2
# 8290             1                3
# 8291             1                4
# 8292             2                1
# 8293             2                2
# 8294             2                3
# 8295             2                4
# 8296             3                1
# 9352             3                1
# 8297             3                2
# 8298             3                3
# 8299             3                4
# 9355             3                4
# 8300             4                1
# 8301             4                2
# 9357             4                2
# 8302             4                3
# 8303             4                4

# %%
# Additional verification: remove any possible duplicates, sort dataset.
print(len(df))
df = df.drop_duplicates()
df = df.sort_values(by=['Puzzle Date', 'Starting Row', 'Starting Column'])
remove_df = (df['Puzzle Date'] == "2024-11-11") & (df['Group Name'] == "CHOCOLATE BARS")
df = df[~remove_df]
print(len(df))
# Out:
# 8372
# 8368

# %%
# Save, update Kaggle dataset
df.to_csv('Connections_Data.csv', index=False)
